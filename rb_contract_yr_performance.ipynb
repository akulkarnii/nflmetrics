# %% [markdown]
# # Running Back Contract Year Performance (2020-2021)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#draft_class_2015 = ['Todd Gurley', 'Melvin Gordon', 'T.J. Yeldon', 'Ameer Abdullah', 'Tevin Coleman', 'Duke Johnson', 'David Johnson', 'Javorious Allen', 'Mike Davis', 'Jay Ajayi']
draft_2016_signed_2020 = ['Derrick Henry', 'Jordan Howard', 'Kenyan Drake', 'Tyler Ervin', 'Devontae Booker', 'DeAndre Washington']
draft_2017_signed_2020 = ['Alvin Kamara', 'Christian McCaffrey', 'Dalvin Cook', 'Joe Mixon', 'Tarik Cohen', 'Kareem Hunt']
draft_2017_signed_2021 = ['Aaron Jones', 'Christopher Carson', 'Jamaal Williams', 'Samaje Perine', 'Marlon Mack', 'James Conner']
draft_2018_signed_2021 = ['Nick Chubb', 'Nyheim Hines', 'Kerryon Johnson', 'Ito Smith', 'Kalen Ballage']
#signed year is first year new contract comes into play
player_stats = pd.read_csv("./year_before_contract.csv")
player_stats
# Out:
#      Rk               Player   Tm  Age  Pos  G1  GS1  Att1  Yds1  TD1  ...  \
# 0    25         Alvin Kamara  NOR   24   RB  14    9   171   797    5  ...
# 1     4  Christian McCaffrey  CAR   23   RB  16   16   287  1387   15  ...
# 2     8          Dalvin Cook  MIN   24   RB  14   14   250  1135   13  ...
# 3     6            Joe Mixon  CIN   23   RB  16   15   278  1137    5  ...
# 4    63          Tarik Cohen  CHI   24   RB  16   11    64   213    0  ...
# 5    86          Kareem Hunt  CLE   24  NaN   8    3    43   179    2  ...
# 6    10          Aaron Jones  GNB   26   RB  14   14   201  1104    9  ...
# 7    31   Christopher Carson  SEA   26   RB  12   12   141   681    5  ...
# 8    40      Jamaal Williams  GNB   25  NaN  14    3   119   505    2  ...
# 9    77        Samaje Perine  CIN   25  NaN  16    1    63   301    3  ...
# 10  231          Marlon Mack  IND   24  NaN   1    1     4    26    0  ...
# 11   19         James Conner  PIT   25   RB  13   11   169   721    6  ...
# 12   14           Nick Chubb  CLE   25   RB  12   12   190  1067   12  ...
# 13   59         Nyheim Hines  IND   24  NaN  16    2    89   380    3  ...
# 14   89      Kerryon Johnson  DET   23  NaN  16    2    52   181    2  ...
# 15   78            Ito Smith  ATL   25  NaN  14    0    63   268    1  ...
# 16   57        Kalen Ballage  2TM   25  NaN  11    2    91   303    3  ...
# 17    1       Derrick Henry   TEN   25   RB  15   15   303  1540   16  ...
# 18   38        Jordan Howard  PHI   25  /rb  10    4   119   525    6  ...
# 19   26         Kenyan Drake  2TM   25  NaN  14   10   170   817    8  ...
# 20  289          Tyler Ervin  2TM   26  NaN  10    0     1    10    0  ...
# 21  249      Devontae Booker  DEN   27  NaN  16    0     2     9    0  ...
# 22   44   DeAndre Washington  OAK   26  NaN  16    3   108   387    3  ...
#
#     Y/G3   G4  GS4  Att4  Yds4  TD4  fD4  Lng4    YA4   Y/G4
# 0   58.9   16    3   120   728    8   42    74    6.1   45.5
# 1   68.6   16   10   117   435    2   22    40    3.7   27.2
# 2   55.9    4    4    74   354    2   16    33    4.8   88.5
# 3   83.4   14    7   178   626    4   39    25    3.5   44.7
# 4   27.8   16    4    87   370    2   19    46    4.3   23.1
# 5   74.9   16   16   272  1327    8   63    69    4.9   82.9
# 6   60.7   12    4    81   448    4   23    46    5.5   37.3
# 7   82.2    4    3    49   208    0   13    30    4.2   52.0
# 8   29.0   16    7   153   556    4   32    25    3.6   34.8
# 9    6.4   16    8   175   603    1   23    30    3.4   37.7
# 10  75.7   14    0    93   358    3   20    35    3.8   25.6
# 11  74.8   14    0    32   144    0    4    23    4.5   10.3
# 12  62.3 -100 -100  -100  -100 -100 -100  -100 -100.0 -100.0
# 13  19.6 -100 -100  -100  -100 -100 -100  -100 -100.0 -100.0
# 14  64.1 -100 -100  -100  -100 -100 -100  -100 -100.0 -100.0
# 15  22.5 -100 -100  -100  -100 -100 -100  -100 -100.0 -100.0
# 16  15.9 -100 -100  -100  -100 -100 -100  -100 -100.0 -100.0
# 17  66.2   16    2   176   744    5   40    75    4.2   46.5
# 18  58.4   16   16   276  1122    9   65    53    4.1   70.1
# 19  33.4   16    6   133   644    3   26    66    4.8   40.3
# 20   0.0    4    0     4    12    0    1     6    3.0    3.0
# 21  11.4   13    0    79   299    1   13    26    3.8   23.0
# 22  11.5   15    0    57   153    2   10    11    2.7   10.2
#
# [23 rows x 44 columns]

# %%
player_stats['fD%D'] = player_stats.apply(lambda r: ((r.fD2 - r.fD1)/r.fD1) * 100, axis = 1)
player_stats['y/a%D'] = player_stats.apply(lambda r: ((r.YA2 - r.YA1)/r.YA1) * 100, axis = 1)
player_stats['s%D'] = player_stats.apply(lambda r: ((r.fc - r.rc)/r.rc) * 100, axis = 1)
player_stats
# Out:
#      Rk               Player   Tm  Age  Pos  G1  GS1  Att1  Yds1  TD1  ...  \
# 0    25         Alvin Kamara  NOR   24   RB  14    9   171   797    5  ...
# 1     4  Christian McCaffrey  CAR   23   RB  16   16   287  1387   15  ...
# 2     8          Dalvin Cook  MIN   24   RB  14   14   250  1135   13  ...
# 3     6            Joe Mixon  CIN   23   RB  16   15   278  1137    5  ...
# 4    63          Tarik Cohen  CHI   24   RB  16   11    64   213    0  ...
# 5    86          Kareem Hunt  CLE   24  NaN   8    3    43   179    2  ...
# 6    10          Aaron Jones  GNB   26   RB  14   14   201  1104    9  ...
# 7    31   Christopher Carson  SEA   26   RB  12   12   141   681    5  ...
# 8    40      Jamaal Williams  GNB   25  NaN  14    3   119   505    2  ...
# 9    77        Samaje Perine  CIN   25  NaN  16    1    63   301    3  ...
# 10  231          Marlon Mack  IND   24  NaN   1    1     4    26    0  ...
# 11   19         James Conner  PIT   25   RB  13   11   169   721    6  ...
# 12   14           Nick Chubb  CLE   25   RB  12   12   190  1067   12  ...
# 13   59         Nyheim Hines  IND   24  NaN  16    2    89   380    3  ...
# 14   89      Kerryon Johnson  DET   23  NaN  16    2    52   181    2  ...
# 15   78            Ito Smith  ATL   25  NaN  14    0    63   268    1  ...
# 16   57        Kalen Ballage  2TM   25  NaN  11    2    91   303    3  ...
# 17    1       Derrick Henry   TEN   25   RB  15   15   303  1540   16  ...
# 18   38        Jordan Howard  PHI   25  /rb  10    4   119   525    6  ...
# 19   26         Kenyan Drake  2TM   25  NaN  14   10   170   817    8  ...
# 20  289          Tyler Ervin  2TM   26  NaN  10    0     1    10    0  ...
# 21  249      Devontae Booker  DEN   27  NaN  16    0     2     9    0  ...
# 22   44   DeAndre Washington  OAK   26  NaN  16    3   108   387    3  ...
#
#     Att4  Yds4  TD4  fD4  Lng4    YA4   Y/G4         fD%D       y/a%D  \
# 0    120   728    8   42    74    6.1   45.5    81.250000    6.382979
# 1    117   435    2   22    40    3.7   27.2   -75.438596  -20.833333
# 2     74   354    2   16    33    4.8   88.5    51.666667   11.111111
# 3    178   626    4   39    25    3.5   44.7   -64.285714  -12.195122
# 4     87   370    2   19    46    4.3   23.1   -80.000000   60.606061
# 5    272  1327    8   63    69    4.9   82.9   450.000000    0.000000
# 6     81   448    4   23    46    5.5   37.3   -28.846154  -14.545455
# 7     49   208    0   13    30    4.2   52.0   -74.418605  -10.416667
# 8    153   556    4   32    25    3.6   34.8    44.827586   -7.142857
# 9    175   603    1   23    30    3.4   37.7   -31.250000   -6.250000
# 10    93   358    3   20    35    3.8   25.6   200.000000  -44.615385
# 11    32   144    0    4    23    4.5   10.3    26.190476  -13.953488
# 12  -100  -100 -100 -100  -100 -100.0 -100.0     8.928571   -1.785714
# 13  -100  -100 -100 -100  -100 -100.0 -100.0   -37.500000   13.953488
# 14  -100  -100 -100 -100  -100 -100.0 -100.0  -100.000000 -100.000000
# 15  -100  -100 -100 -100  -100 -100.0 -100.0   -87.500000   -6.976744
# 16  -100  -100 -100 -100  -100 -100.0 -100.0   -92.000000   -9.090909
# 17   176   744    5   40    75    4.2   46.5    34.246575    5.882353
# 18   276  1122    9   65    53    4.1   70.1   -75.000000  -61.363636
# 19   133   644    3   26    66    4.8   40.3    22.916667  -16.666667
# 20     4    12    0    1     6    3.0    3.0   300.000000  -48.000000
# 21    79   299    1   13    26    3.8   23.0  2000.000000    0.000000
# 22    57   153    2   10    11    2.7   10.2   -91.304348  -19.444444
#
#             s%D
# 0   1455.301869
# 1    271.569923
# 2    693.284032
# 3    780.705504
# 4    657.660608
# 5     84.105554
# 6   1744.780194
# 7    745.797865
# 8    304.586391
# 9    139.130435
# 10   183.723358
# 11   121.412205
# 12   560.969328
# 13   678.760439
# 14   -43.416755
# 15    25.289041
# 16    11.515152
# 17   660.217222
# 18   -88.871819
# 19   903.531228
# 20    45.486111
# 21    53.852255
# 22    60.585866
#
# [23 rows x 47 columns]

# %%
plt.scatter(np.array(player_stats.iloc[:,[12]]), np.array(player_stats.iloc[:,[25]]))

# %%
from sklearn.cluster import KMeans
nnX = np.hstack((np.array(player_stats.iloc[:,[12]]), np.array(player_stats.iloc[:,[25]])))
kmeans = KMeans().fit(nnX)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
X = np.array(player_stats.iloc[:,[5,6,7,8,9,10,11,12,13]])

y = np.array(player_stats.iloc[:,[28]])
y2 = np.array(player_stats.iloc[:,[24]])
y3 = np.array(player_stats.iloc[:,[22]])
y4 = np.array(player_stats.iloc[:,[26]])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y3, test_size=0.40)
mlp = MLPRegressor(solver = 'lbfgs', activation = 'relu', max_iter=1000, hidden_layer_sizes=(1, 2)).fit(X_train,np.ravel(y_train))
mlp.score(X_test, y_test)
# Out:
# 0.12446592944627011

# %%
y
# Out:
# array([[194],
#        [219],
#        [133],
#        [237],
#        [ 99],
#        [181],
#        [133],
#        [247],
#        [121],
#        [  8],
#        [195],
#        [215],
#        [192],
#        [ 85],
#        [118],
#        [ 90],
#        [ 36],
#        [215],
#        [250],
#        [120],
#        [  0],
#        [ 34],
#        [ 30]], dtype=int64)

# %%
X_train
# Out:
# array([[1.500e+01, 1.500e+01, 3.030e+02, 1.540e+03, 1.600e+01, 7.300e+01,
#         7.400e+01, 5.100e+00, 1.027e+02],
#        [1.400e+01, 1.000e+01, 1.700e+02, 8.170e+02, 8.000e+00, 4.800e+01,
#         8.000e+01, 4.800e+00, 5.840e+01],
#        [1.200e+01, 1.200e+01, 1.900e+02, 1.067e+03, 1.200e+01, 5.600e+01,
#         5.900e+01, 5.600e+00, 8.890e+01],
#        [1.600e+01, 1.100e+01, 6.400e+01, 2.130e+02, 0.000e+00, 1.500e+01,
#         1.900e+01, 3.300e+00, 1.330e+01],
#        [1.600e+01, 0.000e+00, 2.000e+00, 9.000e+00, 0.000e+00, 1.000e+00,
#         5.000e+00, 4.500e+00, 6.000e-01],
#        [1.000e+01, 0.000e+00, 1.000e+00, 1.000e+01, 0.000e+00, 1.000e+00,
#         1.000e+01, 1.000e+01, 1.000e+00],
#        [1.600e+01, 1.600e+01, 2.870e+02, 1.387e+03, 1.500e+01, 5.700e+01,
#         8.400e+01, 4.800e+00, 8.670e+01],
#        [1.600e+01, 1.000e+00, 6.300e+01, 3.010e+02, 3.000e+00, 1.600e+01,
#         4.600e+01, 4.800e+00, 1.880e+01],
#        [1.400e+01, 9.000e+00, 1.710e+02, 7.970e+02, 5.000e+00, 3.200e+01,
#         4.000e+01, 4.700e+00, 5.690e+01],
#        [1.600e+01, 2.000e+00, 8.900e+01, 3.800e+02, 3.000e+00, 2.400e+01,
#         3.100e+01, 4.300e+00, 2.380e+01],
#        [1.000e+00, 1.000e+00, 4.000e+00, 2.600e+01, 0.000e+00, 2.000e+00,
#         1.800e+01, 6.500e+00, 2.600e+01],
#        [1.400e+01, 3.000e+00, 1.190e+02, 5.050e+02, 2.000e+00, 2.900e+01,
#         2.500e+01, 4.200e+00, 3.610e+01],
#        [1.400e+01, 1.400e+01, 2.010e+02, 1.104e+03, 9.000e+00, 5.200e+01,
#         7.700e+01, 5.500e+00, 7.890e+01]])

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression().fit(X_train2,y_train2)
print(lin.score(X_test2, y_test2))
y_pred_lin = lin.predict(X_test2)
# Out:
# -2.5255844758057724

# %%
fig, [[ax1, ax2, ax3], [ax4, ax5, ax6], [ax7, ax8, ax9]] = plt.subplots(3, 3, figsize = (25, 16))
ax1.scatter(X_test[:,0], y_test)
ax1.set_title('games played')
ax1.set_xlim(0, 17)
ax1.scatter(X_test[:,0], y_pred_lin)

ax2.scatter(X_test[:,1], y_test)
ax2.set_title('games started')
ax2.scatter(X_test[:,1], y_pred_lin)

ax3.scatter(X_test[:,2], y_test)
ax3.set_title('attempts')
ax3.scatter(X_test[:,2], y_pred_lin)

ax4.scatter(X_test[:,3], y_test)
ax4.set_title('total yards')
ax4.scatter(X_test[:,3], y_pred_lin)

ax5.scatter(X_test[:,4], y_test)
ax5.set_title('touchdowns')
ax5.scatter(X_test[:,4], y_pred_lin)

ax6.scatter(X_test[:,5], y_test)
ax6.set_title('first downs')
ax6.scatter(X_test[:,5], y_pred_lin)

ax7.scatter(X_test[:,6], y_test)
ax7.set_title('long')
ax7.scatter(X_test[:,6], y_pred_lin)

ax8.scatter(X_test[:,7], y_test)
ax8.set_title('y/a')
ax8.scatter(X_test[:,7], y_pred_lin)

ax9.scatter(X_test[:,8], y_test)
ax9.set_title('y/g')
ax9.scatter(X_test[:,8], y_pred_lin)

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
modols = sm.OLS(y, X)
results = modols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     6.302
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):            0.00164
# Time:                        20:39:23   Log-Likelihood:                -113.56
# No. Observations:                  23   AIC:                             247.1
# Df Residuals:                      13   BIC:                             258.5
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        119.8670    165.403      0.725      0.481    -237.464     477.198
# x1            -1.9052      8.118     -0.235      0.818     -19.444      15.634
# x2             6.8026      3.943      1.725      0.108      -1.717      15.322
# x3             0.7481      1.038      0.721      0.484      -1.494       2.991
# x4            -0.2028      0.391     -0.519      0.613      -1.047       0.642
# x5            -3.5553      6.770     -0.525      0.608     -18.181      11.070
# x6            -4.6726      2.579     -1.812      0.093     -10.244       0.899
# x7            -1.3226      0.888     -1.490      0.160      -3.241       0.596
# x8            -8.0274     11.336     -0.708      0.491     -32.517      16.462
# x9             6.1431      3.828      1.605      0.133      -2.127      14.413
# ==============================================================================
# Omnibus:                        0.641   Durbin-Watson:                   2.349
# Prob(Omnibus):                  0.726   Jarque-Bera (JB):                0.712
# Skew:                          -0.271   Prob(JB):                        0.700
# Kurtosis:                       2.330   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X = sm.add_constant(X)
modols = sm.OLS(y2, X)
results = modols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     2.905
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):             0.0398
# Time:                        20:39:25   Log-Likelihood:                -335.03
# No. Observations:                  23   AIC:                             690.1
# Df Residuals:                      13   BIC:                             701.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         5.8e+06   2.51e+06      2.307      0.038    3.68e+05    1.12e+07
# x1         -2.229e+05   1.23e+05     -1.807      0.094    -4.9e+05    4.37e+04
# x2          8.999e+04   5.99e+04      1.501      0.157   -3.95e+04    2.19e+05
# x3         -1267.0033   1.58e+04     -0.080      0.937   -3.54e+04    3.28e+04
# x4          7584.7975   5942.547      1.276      0.224   -5253.295    2.04e+04
# x5          2.919e+05   1.03e+05      2.837      0.014    6.96e+04    5.14e+05
# x6         -7.034e+04   3.92e+04     -1.794      0.096   -1.55e+05    1.44e+04
# x7         -1.094e+04   1.35e+04     -0.810      0.432   -4.01e+04    1.82e+04
# x8         -2.726e+05   1.72e+05     -1.582      0.138   -6.45e+05    9.97e+04
# x9         -9.681e+04   5.82e+04     -1.664      0.120   -2.23e+05    2.89e+04
# ==============================================================================
# Omnibus:                        1.196   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.550   Jarque-Bera (JB):                0.446
# Skew:                           0.330   Prob(JB):                        0.800
# Kurtosis:                       3.170   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
modols = sm.OLS(y3, X)
results = modols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.022
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):              0.471
# Time:                        20:39:29   Log-Likelihood:                -31.380
# No. Observations:                  23   AIC:                             82.76
# Df Residuals:                      13   BIC:                             94.12
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.5793      4.644      0.986      0.342      -5.453      14.612
# x1            -0.0954      0.228     -0.419      0.682      -0.588       0.397
# x2             0.0898      0.111      0.811      0.432      -0.149       0.329
# x3            -0.0437      0.029     -1.499      0.158      -0.107       0.019
# x4             0.0125      0.011      1.136      0.277      -0.011       0.036
# x5            -0.1404      0.190     -0.738      0.473      -0.551       0.270
# x6             0.0611      0.072      0.843      0.414      -0.095       0.217
# x7             0.0025      0.025      0.099      0.922      -0.051       0.056
# x8             0.1643      0.318      0.516      0.614      -0.523       0.852
# x9            -0.0839      0.107     -0.780      0.449      -0.316       0.148
# ==============================================================================
# Omnibus:                       14.734   Durbin-Watson:                   2.507
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.436
# Skew:                          -1.399   Prob(JB):                     0.000445
# Kurtosis:                       5.876   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
modols = sm.OLS(y4, X)
results = modols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     2.199
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):             0.0955
# Time:                        20:39:33   Log-Likelihood:                -53.298
# No. Observations:                  23   AIC:                             126.6
# Df Residuals:                      13   BIC:                             138.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.8151     12.043      1.811      0.093      -4.203      47.833
# x1            -0.0043      0.591     -0.007      0.994      -1.281       1.273
# x2             0.0586      0.287      0.204      0.841      -0.562       0.679
# x3            -0.0846      0.076     -1.119      0.284      -0.248       0.079
# x4             0.0196      0.028      0.689      0.503      -0.042       0.081
# x5            -0.3400      0.493     -0.690      0.502      -1.405       0.725
# x6            -0.0219      0.188     -0.117      0.909      -0.428       0.384
# x7            -0.0568      0.065     -0.878      0.396      -0.196       0.083
# x8            -2.0596      0.825     -2.495      0.027      -3.843      -0.276
# x9             0.1013      0.279      0.363      0.722      -0.501       0.703
# ==============================================================================
# Omnibus:                        0.118   Durbin-Watson:                   2.613
# Prob(Omnibus):                  0.943   Jarque-Bera (JB):                0.324
# Skew:                          -0.100   Prob(JB):                        0.850
# Kurtosis:                       2.454   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#---------------------------------------------------------------------------------------------------------------------------

# %%
ngs = pd.read_csv("./rookie_contract_advanced_stats.csv")
ngs['pay_increase'] = ngs.apply(lambda r: ((r.fc - r.rc)/r.rc) * 100, axis = 1)
ngs['eff_total'] = ngs.apply(lambda r: ((r.eff2019 + r.eff2018 + r.eff2017)), axis = 1)
ngs['ryoe_total'] = ngs.apply(lambda r: ((r.ryoe2019 + r.ryoe2018)), axis = 1)
ngs['ryoe_total'] = ngs.apply(lambda r: 1 if ((r.ryoe2019 - r.ryoe2018 > 0)) else 0, axis = 1)
ngs
# Out:
#                  Player       rc        fc  eff2020  ryoe2020  eff2019  \
# 0          Alvin Kamara   964443  15000000     3.66       101     3.81
# 1   Christian McCaffrey  4310326  16015875     0.00         0     3.46
# 2           Dalvin Cook  1588334  12600000     3.74       251     4.22
# 3             Joe Mixon  1362544  12000000     4.46       -29     3.95
# 4           Tarik Cohen   758915   5750000     0.00         0     0.00
# 5           Kareem Hunt  3259000   6000000     4.01        72     0.00
# 6           Aaron Jones   650484  12000000     3.44       181     3.99
# 7    Christopher Carson   616282   5212500     3.78        52     3.90
# 8       Jamaal Williams   741498   3000000     3.65        25     3.64
# 9         Samaje Perine   690000   1650000     0.00         0     0.00
# 10          Marlon Mack   704912   2000000     0.00         0     3.94
# 11         James Conner   790381   1750000     4.05        39     4.07
# 12       Derrick Henry   1351982  10278000     3.57       411     3.45
# 13        Jordan Howard   647006     72000     0.00         0     3.50
# 14         Kenyan Drake   845315   8483000     3.97       -43     3.66
# 15          Tyler Ervin   720000   1047500     0.00         0     0.00
# 16      Devontae Booker   680848   1047500     3.39        48     0.00
# 17   DeAndre Washington   652299   1047500     0.00         0     4.28
# 18           Nick Chubb  1845774  12200000     3.42       327     3.53
# 19         Nyheim Hines   796137   6200000     3.79         9     0.00
# 20      Kerryon Johnson  1625923    920000     0.00         0     4.03
# 21            Ito Smith   770219    965000     0.00         0     0.00
# 22        Kalen Ballage   825000    920000     4.50       -39     0.00
#
#     ryoe2019  eff2018  ryoe2018  eff2017  Yds1  Yds2  Yds3  pay_increase  \
# 0          6     3.96       -32     3.23   797   932   883   1455.301869
# 1        218     3.44       154     4.63  1387   225  1098    271.569923
# 2        106     3.98        31     0.00  1135  1557   615    693.284032
# 3         13     3.48       171     4.48  1137   428  1168    780.705504
# 4          0     4.96       -34     5.30   213    74   444    657.660608
# 5          0     3.80        90     3.58   179   841   824     84.105554
# 6         71     3.39       137     0.00  1104   799   728   1744.780194
# 7        155     3.65       125     0.00   681   232  1151    745.797865
# 8         -5     4.09       -31     3.62   505   601   464    304.586391
# 9          0     0.00         0     4.46   301   246    32    139.130435
# 10        45     3.50        83     4.64    26   101   908    183.723358
# 11       -36     3.64       132     0.00   721   752   973    121.412205
# 12       305     3.73       256     4.33  1540  2027  1059    660.217222
# 13         8     3.70       -96     4.65   525    60   935    -88.871819
# 14        37     4.05        -2     3.61   817   955   535    903.531228
# 15         0     0.00         0     0.00    10    67     1     45.486111
# 16         0     0.00         0     0.00     9   423   183     53.852255
# 17       -96     0.00         0     0.00   387    91   115     60.585866
# 18       270     3.48       238     0.00  1067  1259   996    560.969328
# 19         0     4.20       -67     0.00   380   276   314    678.760439
# 20       -55     3.41       177     0.00   181     1   641    -43.416755
# 21         0     4.65       -61     0.00   268     4   315     25.289041
# 22         0     0.00         0     0.00   303    36   191     11.515152
#
#     eff_total  ryoe_total
# 0       11.00           1
# 1       11.53           1
# 2        8.20           1
# 3       11.91           0
# 4       10.26           1
# 5        7.38           0
# 6        7.38           0
# 7        7.55           1
# 8       11.35           1
# 9        4.46           0
# 10      12.08           0
# 11       7.71           0
# 12      11.51           1
# 13      11.85           1
# 14      11.32           1
# 15       0.00           0
# 16       0.00           0
# 17       4.28           0
# 18       7.01           1
# 19       4.20           1
# 20       7.44           0
# 21       4.65           1
# 22       0.00           0

# %%
np.mean(ngs.iloc[:,[10]])
# Out:
# Yds1    594.478261
# dtype: float64

# %%
np.mean(ngs.iloc[:,[11]])
# Out:
# Yds2    521.173913
# dtype: float64

# %%
np.mean(ngs.iloc[:,[14]])
# Out:
# eff_total    7.524783
# dtype: float64

# %%
np.mean(ngs.iloc[:,[3,5,7]])
# Out:
# eff2020    2.323043
# eff2019    2.496957
# eff2018    3.004783
# dtype: float64

# %%
ngs['avg_pay'] = ngs.apply(lambda r: 2 if (r.Yds2 > 521 and r.pay_increase > 436.955479) else 1 if ((r.pay_increase > 436.955479)) else 0, axis = 1)
ngs['cyeff'] = ngs.apply(lambda r: ((r.eff2019 - r.eff2018)), axis = 1)
ngs['gbc'] = ngs.apply(lambda r: 2 if (r.pay_increase < 436.955479 and r.eff2020 > 2.323043) else (1 if r.pay_increase > 436.955479 and r.eff2020 > 2.323043 else (0)), axis = 1)
ngs['yd2_yd3'] = ngs.apply(lambda r: (r.Yds2 - r.Yds3)/r.Yds3 if (r.Yds2  > r.Yds3) else ((1+(r.Yds2 - r.Yds3)/(r.Yds3)) if (r.Yds2 + 320 > r.Yds3) else ((r.Yds2 - r.Yds3)/(r.Yds3))), axis=1)
ngs['model_score'] = ngs.apply(lambda r: (.870*r.eff2018 + .836*r.ryoe2018 +.695*r.eff_total+.675*r.yd2_yd3 +.073*r.pay_increase), axis=1)
ngs
# Out:
#                  Player       rc        fc  eff2020  ryoe2020  eff2019  \
# 0          Alvin Kamara   964443  15000000     3.66       101     3.81
# 1   Christian McCaffrey  4310326  16015875     0.00         0     3.46
# 2           Dalvin Cook  1588334  12600000     3.74       251     4.22
# 3             Joe Mixon  1362544  12000000     4.46       -29     3.95
# 4           Tarik Cohen   758915   5750000     0.00         0     0.00
# 5           Kareem Hunt  3259000   6000000     4.01        72     0.00
# 6           Aaron Jones   650484  12000000     3.44       181     3.99
# 7    Christopher Carson   616282   5212500     3.78        52     3.90
# 8       Jamaal Williams   741498   3000000     3.65        25     3.64
# 9         Samaje Perine   690000   1650000     0.00         0     0.00
# 10          Marlon Mack   704912   2000000     0.00         0     3.94
# 11         James Conner   790381   1750000     4.05        39     4.07
# 12       Derrick Henry   1351982  10278000     3.57       411     3.45
# 13        Jordan Howard   647006     72000     0.00         0     3.50
# 14         Kenyan Drake   845315   8483000     3.97       -43     3.66
# 15          Tyler Ervin   720000   1047500     0.00         0     0.00
# 16      Devontae Booker   680848   1047500     3.39        48     0.00
# 17   DeAndre Washington   652299   1047500     0.00         0     4.28
# 18           Nick Chubb  1845774  12200000     3.42       327     3.53
# 19         Nyheim Hines   796137   6200000     3.79         9     0.00
# 20      Kerryon Johnson  1625923    920000     0.00         0     4.03
# 21            Ito Smith   770219    965000     0.00         0     0.00
# 22        Kalen Ballage   825000    920000     4.50       -39     0.00
#
#     ryoe2019  eff2018  ryoe2018  eff2017  ...  Yds2  Yds3  pay_increase  \
# 0          6     3.96       -32     3.23  ...   932   883   1455.301869
# 1        218     3.44       154     4.63  ...   225  1098    271.569923
# 2        106     3.98        31     0.00  ...  1557   615    693.284032
# 3         13     3.48       171     4.48  ...   428  1168    780.705504
# 4          0     4.96       -34     5.30  ...    74   444    657.660608
# 5          0     3.80        90     3.58  ...   841   824     84.105554
# 6         71     3.39       137     0.00  ...   799   728   1744.780194
# 7        155     3.65       125     0.00  ...   232  1151    745.797865
# 8         -5     4.09       -31     3.62  ...   601   464    304.586391
# 9          0     0.00         0     4.46  ...   246    32    139.130435
# 10        45     3.50        83     4.64  ...   101   908    183.723358
# 11       -36     3.64       132     0.00  ...   752   973    121.412205
# 12       305     3.73       256     4.33  ...  2027  1059    660.217222
# 13         8     3.70       -96     4.65  ...    60   935    -88.871819
# 14        37     4.05        -2     3.61  ...   955   535    903.531228
# 15         0     0.00         0     0.00  ...    67     1     45.486111
# 16         0     0.00         0     0.00  ...   423   183     53.852255
# 17       -96     0.00         0     0.00  ...    91   115     60.585866
# 18       270     3.48       238     0.00  ...  1259   996    560.969328
# 19         0     4.20       -67     0.00  ...   276   314    678.760439
# 20       -55     3.41       177     0.00  ...     1   641    -43.416755
# 21         0     4.65       -61     0.00  ...     4   315     25.289041
# 22         0     0.00         0     0.00  ...    36   191     11.515152
#
#     eff_total  ryoe_total  avg_pay  cyeff  gbc    yd2_yd3  model_score
# 0       11.00           1        2  -0.15    1   0.055493    90.612694
# 1       11.53           1        0   0.02    0  -0.795082   159.038074
# 2        8.20           1        2   0.24    1   1.531707    86.721237
# 3       11.91           0        1   0.47    1  -0.633562   210.824898
# 4       10.26           1        1  -4.96    0  -0.833333    30.468624
# 5        7.38           0        0  -3.80    2   0.020631    89.828731
# 6        7.38           0        2   0.60    1   0.097527   250.045185
# 7        7.55           1        1   0.25    1  -0.798436   166.827050
# 8       11.35           1        0  -0.45    2   0.295259     7.964656
# 9        4.46           0        0   0.00    0   6.687500    17.770284
# 10      12.08           0        0   0.44    0  -0.888767    93.640488
# 11       7.71           0        0   0.43    2   0.772867   128.262026
# 12      11.51           1        2  -0.28    1   0.914070   274.073404
# 13      11.85           1        0  -0.20    0  -0.935829   -75.920577
# 14      11.32           1        2  -0.39    1   0.785047    76.206586
# 15       0.00           0        0   0.00    0  66.000000    47.870486
# 16       0.00           0        0   0.00    2   1.311475     4.816461
# 17       4.28           0        0   4.28    0   0.791304     7.931499
# 18       7.01           1        2   0.05    1   0.264056   247.996549
# 19       4.20           1        1  -4.20    1   0.878981     0.703824
# 20       7.44           0        0   0.62    0  -0.998440   152.266130
# 21       4.65           1        0  -4.65    0   0.012698   -41.864079
# 22       0.00           0        0   0.00    2   0.188482     0.967831
#
# [23 rows x 21 columns]

# %%
ngs.groupby('model_score')[['Player','model_score']].max()
# Out:
#                           Player  model_score
# model_score
# -75.920577         Jordan Howard   -75.920577
# -41.864079             Ito Smith   -41.864079
#  0.703824           Nyheim Hines     0.703824
#  0.967831          Kalen Ballage     0.967831
#  4.816461        Devontae Booker     4.816461
#  7.931499     DeAndre Washington     7.931499
#  7.964656        Jamaal Williams     7.964656
#  17.770284         Samaje Perine    17.770284
#  30.468624           Tarik Cohen    30.468624
#  47.870486           Tyler Ervin    47.870486
#  76.206586          Kenyan Drake    76.206586
#  86.721237           Dalvin Cook    86.721237
#  89.828731           Kareem Hunt    89.828731
#  90.612694          Alvin Kamara    90.612694
#  93.640488           Marlon Mack    93.640488
#  128.262026         James Conner   128.262026
#  152.266130      Kerryon Johnson   152.266130
#  159.038074  Christian McCaffrey   159.038074
#  166.827050   Christopher Carson   166.827050
#  210.824898            Joe Mixon   210.824898
#  247.996549           Nick Chubb   247.996549
#  250.045185          Aaron Jones   250.045185
#  274.073404       Derrick Henry    274.073404

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = np.array(ngs.iloc[:,[14, 5, 6, 7, 8, 17, 19, 13]])
y = np.array(ngs.iloc[:,[10]])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5)
lrm = LinearRegression().fit(X_train,y_train)
y_pred = lrm.predict(X_test)
print(X_test)
print(y_pred)
# Out:
# [[ 7.38000000e+00  3.99000000e+00  7.10000000e+01  3.39000000e+00
#    1.37000000e+02  6.00000000e-01  9.75274725e-02  1.74478019e+03]
#  [ 1.13500000e+01  3.64000000e+00 -5.00000000e+00  4.09000000e+00
#   -3.10000000e+01 -4.50000000e-01  2.95258621e-01  3.04586391e+02]
#  [ 1.10000000e+01  3.81000000e+00  6.00000000e+00  3.96000000e+00
#   -3.20000000e+01 -1.50000000e-01  5.54926387e-02  1.45530187e+03]
#  [ 7.55000000e+00  3.90000000e+00  1.55000000e+02  3.65000000e+00
#    1.25000000e+02  2.50000000e-01 -7.98436142e-01  7.45797865e+02]
#  [ 1.13200000e+01  3.66000000e+00  3.70000000e+01  4.05000000e+00
#   -2.00000000e+00 -3.90000000e-01  7.85046729e-01  9.03531228e+02]
#  [ 1.15300000e+01  3.46000000e+00  2.18000000e+02  3.44000000e+00
#    1.54000000e+02  2.00000000e-02 -7.95081967e-01  2.71569923e+02]
#  [ 7.01000000e+00  3.53000000e+00  2.70000000e+02  3.48000000e+00
#    2.38000000e+02  5.00000000e-02  2.64056225e-01  5.60969328e+02]
#  [ 1.20800000e+01  3.94000000e+00  4.50000000e+01  3.50000000e+00
#    8.30000000e+01  4.40000000e-01 -8.88766520e-01  1.83723358e+02]
#  [ 8.20000000e+00  4.22000000e+00  1.06000000e+02  3.98000000e+00
#    3.10000000e+01  2.40000000e-01  1.53170732e+00  6.93284032e+02]
#  [ 1.19100000e+01  3.95000000e+00  1.30000000e+01  3.48000000e+00
#    1.71000000e+02  4.70000000e-01 -6.33561644e-01  7.80705504e+02]
#  [ 7.44000000e+00  4.03000000e+00 -5.50000000e+01  3.41000000e+00
#    1.77000000e+02  6.20000000e-01 -9.98439938e-01 -4.34167547e+01]
#  [ 7.71000000e+00  4.07000000e+00 -3.60000000e+01  3.64000000e+00
#    1.32000000e+02  4.30000000e-01  7.72867420e-01  1.21412205e+02]]
# [[1117.44127458]
#  [ 591.35690689]
#  [ 848.24550325]
#  [1192.03840106]
#  [ 821.1647498 ]
#  [1219.07283644]
#  [1453.91468524]
#  [ 735.77886116]
#  [1070.73056755]
#  [ 733.0232676 ]
#  [ 422.26646523]
#  [ 512.93289588]]

# %%
lrm.coef_
# Out:
# array([[-34.63379369, 113.90386247,   3.95659389,  85.20017259,
#          -0.96363929,  28.70368988,  33.97334688]])

# %%
from sklearn.linear_model import LogisticRegression
X2 = np.array(ngs.iloc[:,[14,7,8,19]])
y2 = np.array(ngs.iloc[:,[16]])
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=.01)
logrm = LogisticRegression(max_iter = 2000).fit(X2_train, y2_train.ravel())
y_pred2 = logrm.predict(X2_train)
print(X2_train)
print(y_pred2)
#ngs['class'] = ngs.apply(lambda r: (2 if ), axis = 1)
# Out:
# [[ 1.13500000e+01  4.09000000e+00 -3.10000000e+01  2.95258621e-01]
#  [ 1.02600000e+01  4.96000000e+00 -3.40000000e+01 -8.33333333e-01]
#  [ 1.18500000e+01  3.70000000e+00 -9.60000000e+01 -9.35828877e-01]
#  [ 4.20000000e+00  4.20000000e+00 -6.70000000e+01  8.78980892e-01]
#  [ 7.01000000e+00  3.48000000e+00  2.38000000e+02  2.64056225e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  6.60000000e+01]
#  [ 7.71000000e+00  3.64000000e+00  1.32000000e+02  7.72867420e-01]
#  [ 7.44000000e+00  3.41000000e+00  1.77000000e+02 -9.98439938e-01]
#  [ 1.13200000e+01  4.05000000e+00 -2.00000000e+00  7.85046729e-01]
#  [ 4.28000000e+00  0.00000000e+00  0.00000000e+00  7.91304348e-01]
#  [ 1.20800000e+01  3.50000000e+00  8.30000000e+01 -8.88766520e-01]
#  [ 8.20000000e+00  3.98000000e+00  3.10000000e+01  1.53170732e+00]
#  [ 7.38000000e+00  3.80000000e+00  9.00000000e+01  2.06310680e-02]
#  [ 1.15100000e+01  3.73000000e+00  2.56000000e+02  9.14069877e-01]
#  [ 4.65000000e+00  4.65000000e+00 -6.10000000e+01  1.26984127e-02]
#  [ 1.15300000e+01  3.44000000e+00  1.54000000e+02 -7.95081967e-01]
#  [ 7.38000000e+00  3.39000000e+00  1.37000000e+02  9.75274725e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.88481675e-01]
#  [ 4.46000000e+00  0.00000000e+00  0.00000000e+00  6.68750000e+00]
#  [ 1.10000000e+01  3.96000000e+00 -3.20000000e+01  5.54926387e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.31147541e+00]
#  [ 7.55000000e+00  3.65000000e+00  1.25000000e+02 -7.98436142e-01]]
# [0 1 0 0 2 0 0 0 0 0 0 0 0 2 1 2 0 0 0 0 0 0]

# %%
X3 = np.array(ngs.iloc[:,[14]])
y3 = np.array(ngs.iloc[:,[13]])
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=.5)
lrm3 = LinearRegression().fit(X_train3,y_train3)
y_pred3 = lrm3.predict(X3)
print(y_pred3)
play_er = np.array(ngs.iloc[:, [0]])
# Out:
# [[396.87144548]
#  [410.53503991]
#  [324.68641833]
#  [420.33157931]
#  [377.79397402]
#  [303.54651751]
#  [303.54651751]
#  [307.92917988]
#  [405.89457388]
#  [228.26784634]
#  [424.71424167]
#  [312.05403857]
#  [410.01943257]
#  [418.7847573 ]
#  [405.12116287]
#  [113.28741022]
#  [113.28741022]
#  [223.6273803 ]
#  [294.00778178]
#  [221.56495096]
#  [305.09333953]
#  [233.16611604]
#  [113.28741022]]

# %%
data3 = np.column_stack((play_er, y_pred3))
np.sort(data3, axis = 0)[::1]
# Out:
# array([['Aaron Jones', 113.28741022017957],
#        ['Alvin Kamara', 113.28741022017957],
#        ['Christian McCaffrey', 113.28741022017957],
#        ['Christopher Carson', 221.56495095702786],
#        ['Dalvin Cook', 223.6273803043964],
#        ['DeAndre Washington', 228.2678463359756],
#        ['Derrick Henry\xa0', 233.1661160359759],
#        ['Devontae Booker', 294.00778178334775],
#        ['Ito Smith', 303.54651751492725],
#        ['Jamaal Williams', 303.54651751492725],
#        ['James Conner', 305.09333952545364],
#        ['Joe Mixon', 307.9291798780854],
#        ['Jordan Howard', 312.0540385728225],
#        ['Kalen Ballage', 324.6864183254547],
#        ['Kareem Hunt', 377.7939740201947],
#        ['Kenyan Drake', 396.8714454833537],
#        ['Kerryon Johnson', 405.12116287282777],
#        ['Marlon Mack', 405.894573878091],
#        ['Nick Chubb', 410.019432572828],
#        ['Nyheim Hines', 410.5350399096702],
#        ['Samaje Perine', 418.7847572991444],
#        ['Tarik Cohen', 420.3315793096708],
#        ['Tyler Ervin', 424.71424167282885]], dtype=object)

# %%
X_test3.shape
# Out:
# (12, 4)

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
modols = sm.OLS(y,X)
results = modols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     6.695
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):            0.00104
# Time:                        21:03:00   Log-Likelihood:                -156.67
# No. Observations:                  23   AIC:                             329.3
# Df Residuals:                      15   BIC:                             338.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        183.6449    154.807      1.186      0.254    -146.318     513.608
# x1            11.2301     28.124      0.399      0.695     -48.716      71.176
# x2            37.9343     41.855      0.906      0.379     -51.278     127.146
# x3             2.3317      0.796      2.929      0.010       0.635       4.028
# x4             7.5597     45.459      0.166      0.870     -89.334     104.454
# x5             0.1749      0.830      0.211      0.836      -1.594       1.944
# x6            30.3747     20.854      1.457      0.166     -14.074      74.823
# x7            -2.4714      4.850     -0.510      0.618     -12.808       7.866
# x8             0.2679      0.139      1.929      0.073      -0.028       0.564
# ==============================================================================
# Omnibus:                        7.504   Durbin-Watson:                   2.212
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                5.259
# Skew:                          -0.928   Prob(JB):                       0.0721
# Kurtosis:                       4.430   Cond. No.                     1.07e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.39e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels.api as sm
X2 = sm.add_constant(X2)
modols = sm.OLS(y2,X2)
results = modols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     1.928
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):              0.138
# Time:                        20:40:04   Log-Likelihood:                -20.084
# No. Observations:                  23   AIC:                             54.17
# Df Residuals:                      16   BIC:                             62.12
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1199      0.386      2.902      0.010       0.302       1.938
# x1            -0.0288      0.117     -0.247      0.808      -0.276       0.218
# x2            -0.0023      0.002     -1.010      0.327      -0.007       0.003
# x3         -3.861e-05      0.001     -0.060      0.953      -0.001       0.001
# x4             0.0010      0.000      2.604      0.019       0.000       0.002
# x5            -0.0732      0.053     -1.386      0.185      -0.185       0.039
# x6            -0.0194      0.012     -1.596      0.130      -0.045       0.006
# ==============================================================================
# Omnibus:                        0.656   Durbin-Watson:                   2.412
# Prob(Omnibus):                  0.720   Jarque-Bera (JB):                0.708
# Skew:                           0.227   Prob(JB):                        0.702
# Kurtosis:                       2.270   Cond. No.                     2.72e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
